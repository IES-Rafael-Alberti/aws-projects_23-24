# %%
# !nvidia-smi
# !nvidia-smi -L
# Out:
# Thu Feb  8 17:21:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.12             Driver Version: 535.104.12   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A10G                    On  | 00000000:00:1E.0 Off |                    0 |
# |  0%   23C    P8              16W / 300W |      2MiB / 23028MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# GPU 0: NVIDIA A10G (UUID: GPU-18656c1d-a0fd-df4b-d56b-a7523b6d9661)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense
# preparar datos
data = np.random.rand(1000, 1) # generar datos aleatorios
timesteps = 10 # número de pasos de tiempo para usar en la entrada
X = np.zeros((data.shape[0]-timesteps, timesteps, data.shape[1]))
y = np.zeros((data.shape[0]-timesteps, data.shape[1]))
for i in range(timesteps, data.shape[0]):
    X[i-timesteps] = data[i-timesteps:i]
    y[i-timesteps] = data[i]
# dividir en conjuntos de entrenamiento y prueba
train_size = int(X.shape[0] * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
# crear red LSTM
model = Sequential()
model.add(LSTM(16, input_shape=(timesteps, data.shape[1])))
model.add(Dense(data.shape[1]))
model.compile(loss='mean_squared_error', optimizer='adam')
# entrenar el modelo
model.fit(X_train, y_train, epochs=100, batch_size=32)
# evaluar el modelo
mse = model.evaluate(X_test, y_test)
print('MSE de prueba:', mse)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Epoch 1/100
# 25/25 [==============================] - 11s 3ms/step - loss: 0.2772
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1009
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0874
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0866
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0863
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0863
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0860
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0860
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0858
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0858
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0857
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0859
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0855
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0856
# Epoch 15/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0859
# Epoch 16/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0854
# Epoch 17/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0852
# Epoch 18/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0854
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0853
# Epoch 20/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0858
# Epoch 21/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0851
# Epoch 22/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0852
# Epoch 23/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0857
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0851
# Epoch 25/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 26/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 27/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 28/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0855
# Epoch 29/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0846
# Epoch 30/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0853
# Epoch 31/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0860
# Epoch 32/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0860
# Epoch 33/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0854
# Epoch 34/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0852
# Epoch 35/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 36/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 37/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 38/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 39/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 40/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 41/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 42/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0855
# Epoch 43/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 44/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 45/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0851
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0848
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0848
# Epoch 48/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0863
# Epoch 49/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0855
# Epoch 50/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 51/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 52/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0853
# Epoch 53/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0851
# Epoch 54/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0858
# Epoch 55/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0855
# Epoch 56/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0856
# Epoch 57/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 58/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 59/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0852
# Epoch 60/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0847
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0850
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0848
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0849
# Epoch 65/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 66/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0849
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0855
# Epoch 68/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 69/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 70/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0853
# Epoch 71/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0847
# Epoch 72/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 73/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0852
# Epoch 74/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0847
# Epoch 76/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 77/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 78/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0851
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0852
# Epoch 80/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 81/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 82/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0846
# Epoch 83/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 84/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 85/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0849
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0857
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0853
# Epoch 89/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0847
# Epoch 91/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0848
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0850
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0848
# Epoch 95/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 96/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 97/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0846
# Epoch 98/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 99/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0854
# 7/7 [==============================] - 1s 46ms/step - loss: 0.0902
# MSE de prueba: 0.09024287015199661
